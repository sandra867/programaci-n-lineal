# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
x=np.linspace(-5,5,100)

# %%
x
# Out:
# array([-5.        , -4.8989899 , -4.7979798 , -4.6969697 , -4.5959596 ,
#        -4.49494949, -4.39393939, -4.29292929, -4.19191919, -4.09090909,
#        -3.98989899, -3.88888889, -3.78787879, -3.68686869, -3.58585859,
#        -3.48484848, -3.38383838, -3.28282828, -3.18181818, -3.08080808,
#        -2.97979798, -2.87878788, -2.77777778, -2.67676768, -2.57575758,
#        -2.47474747, -2.37373737, -2.27272727, -2.17171717, -2.07070707,
#        -1.96969697, -1.86868687, -1.76767677, -1.66666667, -1.56565657,
#        -1.46464646, -1.36363636, -1.26262626, -1.16161616, -1.06060606,
#        -0.95959596, -0.85858586, -0.75757576, -0.65656566, -0.55555556,
#        -0.45454545, -0.35353535, -0.25252525, -0.15151515, -0.05050505,
#         0.05050505,  0.15151515,  0.25252525,  0.35353535,  0.45454545,
#         0.55555556,  0.65656566,  0.75757576,  0.85858586,  0.95959596,
#         1.06060606,  1.16161616,  1.26262626,  1.36363636,  1.46464646,
# ...

# %%
y=(np.sin(x)*np.exp(-0.1*x))

# %%
y
# Out:
# array([ 1.58099885,  1.60381803,  1.60983325,  1.59931928,  1.57271384,
#         1.53060995,  1.47374673,  1.40299895,  1.31936543,  1.22395633,
#         1.11797967,  1.00272699,  0.87955857,  0.74988817,  0.61516753,
#         0.47687087,  0.33647934,  0.19546584,  0.05528015, -0.08266539,
#        -0.2170095 , -0.34645487, -0.46978003, -0.58585034, -0.6936278 ,
#        -0.79217969, -0.88068598, -0.95844545, -1.02488042, -1.07954021,
#        -1.12210318, -1.15237742, -1.17030009, -1.17593556, -1.1694721 ,
#        -1.15121757, -1.12159385, -1.08113027, -1.03045607, -0.97029195,
#        -0.90144097, -0.82477865, -0.74124263, -0.65182184, -0.55754544,
#        -0.45947149, -0.35867559, -0.2562396 , -0.15324042, -0.05073919,
#         0.05022926,  0.14866643,  0.24361957,  0.33419052,  0.41954374,
#         0.49891358,  0.57161068,  0.63702752,  0.69464289,  0.74402555,
#         0.7848368 ,  0.81683207,  0.83986156,  0.85386983,  0.85889452,
# ...

# %%
plt.plot(x,y)
plt.show()
